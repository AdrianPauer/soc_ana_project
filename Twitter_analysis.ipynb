# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianPauer/soc_ana_project/blob/main/Twitter_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
! git clone https://github.com/AdrianPauer/soc_ana_project.git
# Out:
# Cloning into 'soc_ana_project'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 1), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 27.09 MiB | 9.21 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
#read edges
edges = pd.read_csv('soc_ana_project/large_twitch_edges.csv')

# %%
#read features
attributes = pd.read_csv('soc_ana_project/large_twitch_features.csv')
print('features in dataset : ')
print(*attributes.columns)
# Out:
# features in dataset :
# views mature life_time created_at updated_at numeric_id dead_account language affiliate

# %%
plt.hist(attributes.views, log = True)
plt.title('Views distribution')
# Out:
# Text(0.5, 1.0, 'Views distribution')

# %%
# graph construction
graph = nx.from_pandas_edgelist(edges, source = 'numeric_id_1', target = 'numeric_id_2')

# %%
plt.hist(dict(nx.degree(graph)).values(), bins= 50,log = True)
plt.title('Degree distribution')
plt.show()

# %% [markdown]
# ## TASKS:
#
#
# *   Základné cahrakteristiky siete
#     *   hustota, clustering, rozdelenie stupňa vrchola
#     *   Overenie small-world a scale-free valstnosti siete
#
# *   Key player identification - Ktoré vrcholy sú dôležité a ako to súvisí s počtom zhliadnutí?
#     *   centrality measures (degree,betweeness,closenes)
#     *   PageRank algoritmus
#
#
# *   Clustering and homophily - Vieme na základe jazyzka pozorovať skupiny v sieti ?
#     *   homophily, correlation, assortativity
#
# *   Robustnosť siete - porovnanie s náhodnou sieťou
